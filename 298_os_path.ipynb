# %%
import os

# %%
os.path.exists('/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy/')
# Out:
# True

# %%
os.path.isfile('/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy/')
# Out:
# False

# %%
os.path.isdir('/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy/')
# Out:
# True

# %%
os.path.isfile('/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy/header.py')
# Out:
# True

# %%
os.path.basename('/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy/header.py')
# Out:
# 'header.py'

# %%
os.path.dirname('/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy/header.py')
# Out:
# '/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy'

# %%
os.path.split('/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy/header.py')  #split directory path and file name
# Out:
# ('/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy', 'header.py')

# %%
os.path.basename('/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy/header.py')
# Out:
# 'header.py'

# %%
os.path.getmtime('/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy/header.py')   #should be last modified time.
# Out:
# 1750902785.232754

# %%
import time

# %%
time.ctime(os.path.getmtime('/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy/header.py'))  #last modified time
# Out:
# 'Wed Jun 25 21:53:05 2025'

# %%
time.ctime(os.path.getatime('/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy/header.py'))  #last access time
# Out:
# 'Wed Jun 25 21:53:19 2025'

# %%
time.ctime(os.path.getatime('/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy/header.py'))  #i just accessed the file
# Out:
# 'Wed Jun 25 21:53:19 2025'

# %%
#access in vscode didnot change the data

# %%
os.getcwd()
# Out:
# '/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy'

# %%
os.chdir('/Users/jamescavanaugh/Documents/Programming/GitHub')

# %%
os.chdir('/Users/jamescavanaugh/Documents/Programming/GitHub/PythonUdemy')

# %%
os.path.relpath('/Users/jamescavanaugh/Documents/Programming/GitHub/Excercises_CPP/coins.cpp')  #relative path
# Out:
# '../Excercises_CPP/coins.cpp'

# %%
os.path.abspath('../Excercises_CPP/coins.cpp')    #absolute path
# Out:
# '/Users/jamescavanaugh/Documents/Programming/GitHub/Excercises_CPP/coins.cpp'
