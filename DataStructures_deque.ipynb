# %%
from collections import deque

# %%
d = [1,2,3,4,5]
q = deque(d)

# %%
q.appendleft(9)

# %%
q.append(10)

# %%
q
# Out:
# deque([9, 1, 2, 3, 4, 5, 10])

# %%
q.pop()
# Out:
# 10

# %%
q.popleft()
# Out:
# 9

# %%
q
# Out:
# deque([1, 2, 3, 4, 5])

# %%
q.extend([7,8,9])
q.extendleft([22,33,44])

# %%
q
# Out:
# deque([44, 33, 22, 1, 2, 3, 4, 5, 7, 8, 9])

# %%
q.rotate(2)

# %%
q
# Out:
# deque([8, 9, 44, 33, 22, 1, 2, 3, 4, 5, 7])
