# %%
import statistics as s

# %%
L=[1,2,3,4,5,6]

# %%
s.mean(L)
# Out:
# 3.5

# %%
s.harmonic_mean(L)   #count of items divided by the sum of their reciprical value. 6 / (1/1+1/2+1/3+1/4+1/5+1/6)
# Out:
# 2.4489795918367347

# %%
s.fsum(L)
# Out:
# 21.0

# %%
s.median(L)
# Out:
# 3.5

# %%
s.mode(L)
# Out:
# 1

# %%
L.append(6)

# %%
L
# Out:
# [1, 2, 3, 4, 5, 6, 6]

# %%
s.mode(L)   #most frequently occuring value
# Out:
# 6

# %%
s.median_high(L)
# Out:
# 4

# %%
s.median_low(L)
# Out:
# 4

# %%
print(L.pop())
# Out:
# 6

# %%
s.median_low(L)
# Out:
# 3

# %%
s.median_high(L)
# Out:
# 4

# %%
s.pstdev([2,2,4,2,3,2,5,2])    #standard deviation of the list. When you use p    this is also the sqrt of the variance
# Out:
# 1.0897247358851685

# %%
s.pvariance([2,2,4,2,3,2,5,2])
# Out:
# 1.1875

# %%
s.stdev([2,2,4,2,3,2,5,2])    #includes a portion of the list
# Out:
# 1.164964745021435

# %%
s.variance([2,2,4,2,3,2,5,2])
# Out:
# 1.3571428571428572
