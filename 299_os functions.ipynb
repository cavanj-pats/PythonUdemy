# %%
import os

# %%
os.getlogin()
# Out:
# 'james'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\james\\Documents\\GItHub\\PythonUdemy'

# %%
#os.chdir(xxxx) to change directory to xxxx

# %%
os.getcwd()
# Out:
# 'C:\\Users\\james\\Documents\\GItHub\\PythonUdemy'

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '.venv',
#  '.vscode',
#  'bankAccountWithdrawal_exceptionHndl.py',
#  'bankDB.db',
#  'binaryFileWriteRead.py',
#  'bisect_module.ipynb',
#  'challenge_BankAccount.py',
#  'challenge_CircleClass.py',
#  'challenge_dateTime_countMondayMonths.py',
#  'challenge_dateTime_countSundaysInYear.py',
#  'challenge_dateTime_DateOfBirth.py',
#  'challenge_dateTime_PreviousThursday.py',
#  'challenge_dateTime_StringToObjectDate.py',
#  'challenge_DS_array_findFirstDuplicate.py',
#  'challenge_DS_array_findMissingNumber.py',
#  'challenge_DS_BarberShopQueue.py',
#  'challenge_DS_GroceryBillWithSubtotal.py',
#  'challenge_DS_HeapSort.py',
#  'challenge_DS_IntegersHighestProduct.py',
#  'challenge_DS_Inventory.py',
#  'challenge_DS_ThreeMostCommonWords.py',
#  'challenge_EventPlanner.py',
#  'challenge_flattenList.py',
#  'challenge_InventoryTracker.py',
#  'challenge_OrderObject.py',
#  'challenge_PaymentMethod.py',
# ...

# %%
#os.mkdir(xx)   #make directory    like c:\poop
#os.makedirs(yy)   #make more than one directory like c:\poop\fart\apple

# %%
#os.remove(file)   #remove a file
#os.rmdir(folder)  #remove folder
#os.removedirs( enter drive and folders)

# %%
#make sure folder is empty

# %%
os.rename( folder)   #change name of folder
