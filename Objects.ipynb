# %%
x = 10
print(isinstance(x,int))
# Out:
# True

# %%
print(isinstance(x,float))
# Out:
# False

# %%
x='Text'
print(hasattr(x,'lower'))
# Out:
# True

# %%
print(x)
# Out:
# Text

# %%
x = 'Text'
print(x)
print(repr(x))
# Out:
# Text
# 'Text'

# %%
list1=[1, -3, 7, 11]
sorted(list1)
# Out:
# [-3, 1, 7, 11]

# %%
sorted(list1, reverse=True)
# Out:
# [11, 7, 1, -3]

# %%
sorted(list1,key=abs)
# Out:
# [1, -3, 7, 11]

# %%
#very cool

# %%
s=slice(3)
list1[s]
# Out:
# [1, -3, 7]

# %%
l1 = list1[s]
it=iter(l1)
next(it)
# Out:
# 1

# %%
next(it)
# Out:
# -3

# %%
next(it)
# Out:
# 7

# %%
next(it)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 next(it)
#
# StopIteration:

# %%
if next(it)=='StopIteration' :
# Out:
#   Cell In[15], line 1
#     if next(it)=='StopIteration' :
#                                   ^
# SyntaxError: incomplete input
