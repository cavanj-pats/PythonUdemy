# %%
import math

# %%
math.ceil(12.1)
# Out:
# 13

# %%
math.floor(12.99)
# Out:
# 12

# %%
math.fmod(12,5)
# Out:
# 2.0

# %%
math.remainder(12,5)
# Out:
# 2.0

# %%
math.sqrt(35)
# Out:
# 5.916079783099616

# %%
math.isqrt(35)   #integer portion of sqrt
# Out:
# 5

# %%
math.pow(6,2)
# Out:
# 36.0

# %%
math.factorial(4)   #factorial
# Out:
# 24

# %%
math.gcd(35,21)
# Out:
# 7

# %%
math.perm(6,3)  #permutations
# Out:
# 120

# %%
math.comb(6,3)   #combinations
# Out:
# 20

# %%
math.prod([2,4,6])   #product
# Out:
# 48

# %% [markdown]
# math.fsum([6,3,1])  #sum

# %%
math.fsum([0,9,7])   #sum
# Out:
# 16.0

# %%
math.degrees(3.141593)
# Out:
# 180.00001984784282

# %%
math.radians(90)
# Out:
# 1.5707963267948966

# %%
math.sin(30)
# Out:
# -0.9880316240928618

# %%
math.cos(60)
# Out:
# -0.9524129804151563

# %%
math.tan(45)
# Out:
# 1.6197751905438615

# %%
math.sin(math.pi/6)
# Out:
# 0.49999999999999994

# %%
math.cos(math.pi/3)
# Out:
# 0.5000000000000001

# %%
math.tan(math.pi/4)
# Out:
# 0.9999999999999999

# %%
math.log(10,2)
# Out:
# 3.3219280948873626

# %%
math.log10(10)
# Out:
# 1.0

# %%
math.log2(10)
# Out:
# 3.321928094887362

# %%
math.log2(1024)
# Out:
# 10.0

# %%
math.log2(math.pow(2,8))
# Out:
# 8.0

# %%
math.log(math.e)
# Out:
# 1.0

# %%
math.pi
math.e
math.nan    #not a number 
math.inf   #infinity
# Out:
# inf

# %%
math.nan
# Out:
# nan

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793
