# %%
d1 = {1:'One', 2:'Two',3:'Three', 4:'Four'}

# %%
d1
# Out:
# {1: 'One', 2: 'Two', 3: 'Three', 4: 'Four'}

# %%
d1[1]
# Out:
# 'One'

# %%
for i in d1:
    print (i, d1[i])
# Out:
# 1 One
# 2 Two
# 3 Three
# 4 Four

# %%
#can make a disctionary from a tuple  aka iterable pair
t = [('apple','fruit'),('tomato','fruit'),('corn','veg')]
d1 = dict(t)
d1
# Out:
# {'apple': 'fruit', 'tomato': 'fruit', 'corn': 'veg'}

# %%
#d1 is made using the dict function and passing it the tuple, t

# %%
##using the zip function.  Take two lists and zip together like using a zipper
L1 = (1,2,3,4)
L2 = ('One', 'Two', 'Tres', 'Four')
D1 = dict(zip(L1,L2))
type(D1)
# Out:
# dict

# %%
#can also use the enumerate function
lst = ['apple', 'banana', 'orange', 'yellow']
d1 = dict(enumerate(lst,  start = 1))

# %%
d1
# Out:
# {1: 'apple', 2: 'banana', 3: 'orange', 4: 'yellow'}

# %%
d2 = dict(enumerate(lst))

# %%
d2
# Out:
# {0: 'apple', 1: 'banana', 2: 'orange', 3: 'yellow'}

# %%
##  the start operator indicates the starting index.

# %%
# can use FOR loop to create a Dictionary
#start with tuple of iterable or ordered pairs

# %%
t1 = [(1,'One'),(2,'Two'),(3,'Tres'),(4,'Quattro')]
d9 = {x:y for x,y in t1}

# %%
d9
# Out:
# {1: 'One', 2: 'Two', 3: 'Tres', 4: 'Quattro'}

# %%
#you can also iterate through a zip function results similarly
d10 = { x:y for x,y in zip(L1, L2)}

# %%
d10
# Out:
# {1: 'One', 2: 'Two', 3: 'Tres', 4: 'Four'}

# %%
#  Can do same using enumerate function

# %%
d11 = {x:y for x,y in enumerate(L2, start = 1)}

# %%
d11
# Out:
# {1: 'One', 2: 'Two', 3: 'Tres', 4: 'Four'}

# %%
d11.keys()
# Out:
# dict_keys([1, 2, 3, 4])

# %%
for x in d11.keys():
    print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
##using of keys()

# %%
for x in d11.values():
    print (x)
# Out:
# One
# Two
# Tres
# Four

# %%
##  using values()

# %%
d11[4]
# Out:
# 'Four'

# %%
d11.get(4)
# Out:
# 'Four'

# %%
## using methods that return a specific value.
##   ###   d11[5} will return an ERROR while d11.get(5) will return NULL or simply nothing.

# %%
d11.get(5, 'Missing')
# Out:
# 'Missing'

# %%
# returns Missing as an alternate value to use for this exact case,  where the index is NULL

# %%
#  the Missing value is not added to the dictionary.

# %% [markdown]
# d11.setdefaultvalue(3)

# %%
d11
# Out:
# {1: 'One', 2: 'Two', 3: 'Tres', 4: 'Four'}

# %%
d11.setdefault(3)
# Out:
# 'Tres'

# %%
d11.setdefault(5)

# %%
d11
# Out:
# {1: 'One', 2: 'Two', 3: 'Tres', 4: 'Four', 5: None}

# %%
#  5 inserted with None

# %%
d11.setdefault(6,'undefined')
# Out:
# 'undefined'

# %%
d11
# Out:
# {1: 'One', 2: 'Two', 3: 'Tres', 4: 'Four', 5: None, 6: 'undefined'}

# %%
#  6 is added with an value of undefined

# %%
D1
# Out:
# {1: 'One', 2: 'Two', 3: 'Tres', 4: 'Four'}

# %%
d11.clear()   #empties the dictionary

# %%
d11.update(D1)     #updates d11 with the contents of D1.  Since d11 is empty,  d11 will be filled with the contents of D1

# %%
d11
# Out:
# {1: 'One', 2: 'Two', 3: 'Tres', 4: 'Four'}

# %%
d11.update(dict([(5,'Five')]))

# %%
d11
# Out:
# {1: 'One', 2: 'Two', 3: 'Tres', 4: 'Four', 5: 'Five'}

# %%
r = range(4)

# %%
print(r)
# Out:
# range(0, 4)

# %%
it = iter(r)

# %%
print(it)

# %%
next(it)
# Out:
# 0

# %%
next(it)
# Out:
# 1

# %%
next(it)
# Out:
# 2
