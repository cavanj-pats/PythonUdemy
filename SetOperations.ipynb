# %% [markdown]
# s1={1,2,3,5,7}
# s2={5,7,9,10,11}

# %%
s3 = s1.union(s2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 s3 = s1.union(s2)
#
# NameError: name 's1' is not defined

# %%
type(s1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 type(s1)
#
# NameError: name 's1' is not defined

# %%
s1={1,2,3,5,7}

# %%
type(s1)
# Out:
# set

# %%
s2 ={5,7,9,10,11}

# %%
s3 = s1.union(s2)

# %%
s3
# Out:
# {1, 2, 3, 5, 7, 9, 10, 11}

# %%
s4 = s1.intersection(s2)

# %%
s4
# Out:
# {5, 7}

# %%
s5 = s1

# %%
s5.intersection_update(s2)

# %%
s5
# Out:
# {5, 7}

# %%
s6 = s1.difference(s2)

# %%
s1
# Out:
# {5, 7}

# %%
s2
# Out:
# {5, 7, 9, 10, 11}

# %%
s6 = s3.difference(s2)

# %%
s6
# Out:
# {1, 2, 3}

# %%
s2
# Out:
# {5, 7, 9, 10, 11}

# %%
s3
# Out:
# {1, 2, 3, 5, 7, 9, 10, 11}

# %%
d1={1,2,3,5,7}

# %%
d2={5,7,9,10,11}

# %%
d1.difference_update(d2)

# %%
d1
# Out:
# {1, 2, 3}

# %%
#

# %%
q1 = {1,2,3,5,7}

# %%
q2 = {5,7,9,10,11}

# %%
q3=q1.symmetric_difference(q2)

# %%
q3
# Out:
# {1, 2, 3, 9, 10, 11}

# %%
#above takes elements unique,  common elements are not taken

# %%
q1.symmetric_difference_update(q2)

# %%
q1
# Out:
# {1, 2, 3, 9, 10, 11}

# %%
#operators
#   |  union
#   &  intersection
#   &= intersection_update
#   -  difference
#   -= difference_update
#   ^  symmetric_difference
#   ^= symmetric_difference_update

# %%
s1 = {1,3,5}

# %%
s2 = {5,7,9}

# %%
s3 = s1 | s2

# %%
s3
# Out:
# {1, 3, 5, 7, 9}

# %%
s4 = s1 & s2

# %%
s4
# Out:
# {5}
