# %%
import datetime as dt

# %%
dt.date.today()
# Out:
# datetime.date(2026, 2, 8)

# %%
d1 = dt.date(2026, 2, 10)

# %%
d1
# Out:
# datetime.date(2026, 2, 10)

# %%
print(d1)
# Out:
# 2026-02-10

# %%
d1.strftime('%d-%m-%y')
# Out:
# '10-02-26'

# %%
d1.strftime('%d-%m-%Y')
# Out:
# '10-02-2026'

# %%
d1.strftime('%d-%A, %B, %Y')
# Out:
# '10-Tuesday, February, 2026'

# %%
t1 = dt.time(10, 30, 15)

# %%
t1
# Out:
# datetime.time(10, 30, 15)

# %%
print(t1)
# Out:
# 10:30:15

# %%
t1.strftime('%H:%M:%S')
# Out:
# '10:30:15'

# %%
dt.datetime.today()
# Out:
# datetime.datetime(2026, 2, 8, 13, 32, 37, 504069)

# %%
dt.datetime.now()
# Out:
# datetime.datetime(2026, 2, 8, 13, 32, 45, 641350)

# %%
dt1 = dt.datetime(2026,2,1,8,30,0,0)

# %%
dt2 = dt.datetime.now()

# %%
dt2-dt1
# Out:
# datetime.timedelta(days=7, seconds=18289, microseconds=679266)

# %%
s1 = '1/8/2025 16:30:45'
dt3 = dt.datetime.strptime(s1, '%m/%d/%Y %H:%M:%S')

# %%
print (dt3)
# Out:
# 2025-01-08 16:30:45

# %%
dt3
# Out:
# datetime.datetime(2025, 1, 8, 16, 30, 45)
