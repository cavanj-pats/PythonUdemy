# %%
import time

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=2, tm_mday=8, tm_hour=14, tm_min=33, tm_sec=37, tm_wday=6, tm_yday=39, tm_isdst=0)

# %%
time.ctime()
# Out:
# 'Sun Feb  8 14:38:09 2026'

# %%
time.ctime(365*24*60*60)
# Out:
# 'Thu Dec 31 19:00:00 1970'

# %%
time.ctime(0)
# Out:
# 'Wed Dec 31 19:00:00 1969'

# %%
time.time()
# Out:
# 1770579848.9791117

# %%
#number of seconds since time(0)

# %%
t1 = time.process_time()

# %%
for i in range(100000):
    pass

t2 = time.process_time()
print(t1, t2, t2-t1)
# Out:
# 1.71875 1.75 0.03125

# %%
# Out:
# 1.65625 1.65625 0.0
