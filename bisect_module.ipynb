# %%
import bisect as b

# %%
lst = [3,5,6,9,12]

# %%
b.insort(lst, 7)

# %%
print(lst)
# Out:
# [3, 5, 6, 7, 9, 12]

# %%
lst1 = [3,5,5,5,7,7,9,12]

# %%
b.bisect_left(lst1,5)
# Out:
# 1

# %%
b.bisect_right(lst1, 5)
# Out:
# 4

# %%
#that is where it would be inserted

# %%
import datetime as dt

# %%
dt.date.today()
# Out:
# datetime.date(2026, 2, 7)
